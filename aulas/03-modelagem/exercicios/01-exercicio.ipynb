# %% [markdown]
# ## Exercício 1
# ### Verificar a documentação dos modelos RandomForestClassifier, LogisticRegression, KNeighborsClassifier, GradientBoostingClassifier e altere ou inclua algum parâmetro dos modelos e compare os resultados com o baseline executado nesse notebook.

# %% [markdown]
# ### Import libs

# %%
# %pip install pandas
# %pip install sklearn
# %pip install mlflow

# Manipulação e visualização de dados
import pandas as pd
import time

# Bibliotecas para aprendizado de máquina
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score


# MLflow para gerenciamento de experimentos
import mlflow

# Supressão de avisos
import warnings
warnings.filterwarnings("ignore")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/vand/Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /Users/vand/Library/Python/3.9/lib/python/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/vand/Library/Python/3.9/lib/python/site-packages (from sklearn) (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (1.5.2)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlflow in /Users/vand/Library/Python/3.9/lib/python/site-packages (3.1.4)
# Requirement already satisfied: graphene<4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: mlflow-skinny==3.1.4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: matplotlib<4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.9.4)
# Requirement already satisfied: numpy<3 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: scikit-learn<2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: Flask<4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.0.44)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: scipy<2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.16.5)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow) (20.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (1.38.0)
# Requirement already satisfied: fastapi<1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.120.1)
# Requirement already satisfied: packaging<26 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (25.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.70.0)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.7.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.45)
# Requirement already satisfied: uvicorn<1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.38.0)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (2.32.5)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.0.3)
# Requirement already satisfied: cloudpickle<4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (4.15.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (1.38.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.1.8)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.33.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (2.12.3)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.2.1)
# Requirement already satisfied: Mako in /Users/vand/Library/Python/3.9/lib/python/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: tomli in /Users/vand/Library/Python/3.9/lib/python/site-packages (from alembic!=1.10.0,<2->mlflow) (2.3.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.42.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.49.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.0.3)
# Requirement already satisfied: blinker>=1.9.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.4->mlflow) (3.23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: pillow>=8 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (6.5.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.4->mlflow) (0.59b0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.6.1)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (2.41.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (2025.10.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.11)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: greenlet>=1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /Users/vand/Library/Python/3.9/lib/python/site-packages (from uvicorn<1->mlflow-skinny==3.1.4->mlflow) (0.16.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Constants

# %%
DATA_PATH = "../data"

# %% [markdown]
# ### Carrega dados

# %%
x_train = pd.read_csv(f"{DATA_PATH}/x_train.csv")
x_test = pd.read_csv(f"{DATA_PATH}/x_test.csv")
y_train = pd.read_csv(f"{DATA_PATH}/y_train.csv")
y_test = pd.read_csv(f"{DATA_PATH}/y_test.csv")

# %% [markdown]
# #### Utils

# %%
def avalia_modelo(models):
    results = []

    for name, model_value in models.items():
        model = model_value["model"]
        params = model_value["params"]

        inicio = time.time()
        model.fit(x_train, y_train)  # Treinamento
        fim = time.time()

        # Previsões
        y_pred = model.predict(x_test)

        # Métricas
        acuracia = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average="weighted")
        tempo_treino = fim - inicio

        # Registrar no MLflow
        with mlflow.start_run(run_name=name):
            mlflow.log_param("Modelo", name)

            for param_key, param_value in params.items():
                mlflow.log_param(param_key, param_value)

            mlflow.log_metric("Acurácia", acuracia)
            mlflow.log_metric("F1-Score", f1)
            mlflow.log_metric("Tempo de Treinamento", tempo_treino)
            mlflow.sklearn.log_model(model, "modelo")

        # Armazenar resultados
        results.append({
            "Modelo": name,
            "Acurácia": acuracia,
            "F1-Score": f1,
            "Tempo de Treinamento (s)": tempo_treino,
            "model": model,
            "params": params
        })
        print(f"Modelo {name} treinado e registrado no MLflow.")

    df_results = pd.DataFrame(results)
    return check_best_df(df_results)

def check_best_df(df: pd.DataFrame):
    df.sort_values(by=["Acurácia", "Tempo de Treinamento (s)"], ascending=[False, True], inplace=True)
    print("Resultado da comparação:")
    print(df)
    df_best = df.iloc[0]
    print(f"Melhor Modelo: {df_best['Modelo']}")
    return df_best

# %% [markdown]
# #### Randon Forest

# %%
randon_forest_baseline_key = "Random Forest"

randon_forest_models = {
    "Random Forest": {
        "model": RandomForestClassifier(random_state=42),
        "params": {
            "random_state": 42
        }
    },
    "Random Forest with 500 estimators": {
        "model": RandomForestClassifier(random_state=42, n_estimators=500),
        "params": {
            "random_state": 42,
            "n_estimators": 500
        }
    },
    "Random Forest with 10 max depth": {
        "model": RandomForestClassifier(random_state=42, max_depth=10),
        "params": {
            "random_state": 42,
            "max_depth": 10
        }
    },
    "Random Forest with 500 estimators and 10 max depth": {
        "model": RandomForestClassifier(random_state=42, n_estimators=500, max_depth=10),
        "params": {
            "random_state": 42,
            "n_estimators": 500,
            "max_depth": 10
        }
    },
}

best_radon_forest = avalia_modelo(randon_forest_models)
# Out:
# 2025/11/02 01:49:09 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:49:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Random Forest treinado e registrado no MLflow.
# 2025/11/02 01:49:16 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:49:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Random Forest with 500 estimators treinado e registrado no MLflow.
# 2025/11/02 01:49:20 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:49:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Random Forest with 10 max depth treinado e registrado no MLflow.
# 2025/11/02 01:49:25 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:49:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Random Forest with 500 estimators and 10 max depth treinado e registrado no MLflow.
# Resultado da comparação:
#                                               Modelo  Acurácia  F1-Score  \
# 0                                      Random Forest  0.821229  0.818174
# 1                  Random Forest with 500 estimators  0.810056  0.806810
# 2                    Random Forest with 10 max depth  0.787709  0.780354
# 3  Random Forest with 500 estimators and 10 max d...  0.776536  0.765034
#
#    Tempo de Treinamento (s)  \
# 0                  0.442809
# 1                  1.881878
# 2                  0.251360
# 3                  0.934243
#
#                                                model  \
# 0  (DecisionTreeClassifier(max_features='sqrt', r...
# 1  (DecisionTreeClassifier(max_features='sqrt', r...
# 2  (DecisionTreeClassifier(max_depth=10, max_feat...
# 3  (DecisionTreeClassifier(max_depth=10, max_feat...
#
#                                               params
# 0                               {'random_state': 42}
# 1          {'random_state': 42, 'n_estimators': 500}
# 2              {'random_state': 42, 'max_depth': 10}
# 3  {'random_state': 42, 'n_estimators': 500, 'max...
# Melhor Modelo: Random Forest

# %% [markdown]
# #### Logistic Regression

# %%
logistic_regression_baseline_key = "Logistic Regression"

logistic_regression_models = {
    "Logistic Regression": {
        "model": LogisticRegression(max_iter=1000, random_state=42),
        "params": {
            "max_iter": 1000,
            "random_state": 42,
        }
    },
    "Logistic Regression with 10 intercept scaling": {
        "model": LogisticRegression(max_iter=1000, random_state=42, intercept_scaling=10),
        "params": {
            "max_iter": 1000,
            "random_state": 42,
            "intercept_scaling": 10
        }
    },
    "Logistic Regression with False fit intercept": {
        "model": LogisticRegression(max_iter=1000, random_state=42, fit_intercept=False),
        "params": {
            "max_iter": 1000,
            "random_state": 42,
            "fit_intercept": False
        }
    },
    "Logistic Regression with 10 intercept scaling and False fit intercept": {
        "model": LogisticRegression(max_iter=1000, random_state=42, intercept_scaling=10, fit_intercept=False),
        "params": {
            "max_iter": 1000,
            "random_state": 42,
            "intercept_scaling": 10,
            "fit_intercept": False
        }
    },
}

best_logistic_regression = avalia_modelo(logistic_regression_models)
# Out:
# 2025/11/02 01:49:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:49:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/11/02 01:49:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Modelo Logistic Regression treinado e registrado no MLflow.
# 2025/11/02 01:49:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/11/02 01:49:34 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Modelo Logistic Regression with 10 intercept scaling treinado e registrado no MLflow.
# 2025/11/02 01:49:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/11/02 01:49:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Modelo Logistic Regression with False fit intercept treinado e registrado no MLflow.
# 2025/11/02 01:49:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Logistic Regression with 10 intercept scaling and False fit intercept treinado e registrado no MLflow.
# Resultado da comparação:
#                                               Modelo  Acurácia  F1-Score  \
# 2       Logistic Regression with False fit intercept  0.821229  0.819935
# 3  Logistic Regression with 10 intercept scaling ...  0.821229  0.819935
# 1      Logistic Regression with 10 intercept scaling  0.821229  0.819935
# 0                                Logistic Regression  0.821229  0.819935
#
#    Tempo de Treinamento (s)  \
# 2                  0.057311
# 3                  0.058075
# 1                  0.058624
# 0                  0.079705
#
#                                                model  \
# 2  LogisticRegression(fit_intercept=False, max_it...
# 3  LogisticRegression(fit_intercept=False, interc...
# 1  LogisticRegression(intercept_scaling=10, max_i...
# 0  LogisticRegression(max_iter=1000, random_state...
#
#                                               params
# 2  {'max_iter': 1000, 'random_state': 42, 'fit_in...
# 3  {'max_iter': 1000, 'random_state': 42, 'interc...
# 1  {'max_iter': 1000, 'random_state': 42, 'interc...
# 0             {'max_iter': 1000, 'random_state': 42}
# Melhor Modelo: Logistic Regression with False fit intercept

# %% [markdown]
# #### K Neighbors Classifier

# %%
k_neighbors_classifier_baseline_key = "K-Nearest Neighbors"

k_neighbors_classifier_models = {
    "K Neighbors Classifier": {
        "model": KNeighborsClassifier(),
        "params": {}
    },
    "K Neighbors Classifier with 10 in neighbors": {
        "model": KNeighborsClassifier(n_neighbors=10),
        "params": {
            "n_neighbors": 10
        }
    },
    "K Neighbors Classifier with 50 leaf size": {
        "model": KNeighborsClassifier(leaf_size=50),
        "params": {
            "leaf_size": 50
        }
    },
    "K Neighbors Classifier with 10 in neighbors and  50 leaf size": {
        "model": KNeighborsClassifier(n_neighbors=10, leaf_size=50),
        "params": {
            "n_neighbors": 50,
            "leaf_size": 50
        }
    },
}

best_k_neighbors_classifier = avalia_modelo(k_neighbors_classifier_models)
# Out:
# 2025/11/02 01:49:40 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:49:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/11/02 01:49:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Modelo K Neighbors Classifier treinado e registrado no MLflow.
# 2025/11/02 01:49:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/11/02 01:49:47 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Modelo K Neighbors Classifier with 10 in neighbors treinado e registrado no MLflow.
# 2025/11/02 01:49:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/11/02 01:49:50 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Modelo K Neighbors Classifier with 50 leaf size treinado e registrado no MLflow.
# 2025/11/02 01:49:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo K Neighbors Classifier with 10 in neighbors and  50 leaf size treinado e registrado no MLflow.
# Resultado da comparação:
#                                               Modelo  Acurácia  F1-Score  \
# 1        K Neighbors Classifier with 10 in neighbors  0.810056  0.805268
# 3  K Neighbors Classifier with 10 in neighbors an...  0.810056  0.805268
# 2           K Neighbors Classifier with 50 leaf size  0.804469  0.803325
# 0                             K Neighbors Classifier  0.804469  0.803325
#
#    Tempo de Treinamento (s)  \
# 1                  0.029608
# 3                  0.031187
# 2                  0.029382
# 0                  0.032176
#
#                                                model  \
# 1               KNeighborsClassifier(n_neighbors=10)
# 3  KNeighborsClassifier(leaf_size=50, n_neighbors...
# 2                 KNeighborsClassifier(leaf_size=50)
# 0                             KNeighborsClassifier()
#
#                                  params
# 1                   {'n_neighbors': 10}
# 3  {'n_neighbors': 50, 'leaf_size': 50}
# 2                     {'leaf_size': 50}
# 0                                    {}
# Melhor Modelo: K Neighbors Classifier with 10 in neighbors

# %% [markdown]
# #### Gradient Boosting

# %%
gradient_boosting_classifier_baseline_key = "Gradient Boosting"

gradient_boosting_classifier_models = {
    "Gradient Boosting": {
        "model": GradientBoostingClassifier(random_state=42),
        "params": {
            "randon_state": 42
        }
    },
    "Gradient Boosting with 200 n estimators": {
        "model": GradientBoostingClassifier(random_state=42, n_estimators=200),
        "params": {
            "random_state": 42,
            "n_estimators": 200
        }
    },
    "Gradient Boosting with 10 max depth": {
        "model": GradientBoostingClassifier(random_state=42, max_depth=10),
        "params": {
            "random_state": 42,
            "max_depth": 10
        }
    },
    "Gradient Boosting with 200 n estimators and 10 max depth": {
        "model": GradientBoostingClassifier(random_state=42, n_estimators=200, max_depth=10),
        "params": {
            "random_state": 42,
            "n_estimators": 200,
            "max_depth": 10
        }
    },
}

best_gradient_boosting_classifier = avalia_modelo(gradient_boosting_classifier_models)
# Out:
# 2025/11/02 01:49:55 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:49:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Gradient Boosting treinado e registrado no MLflow.
# 2025/11/02 01:50:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:50:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Gradient Boosting with 200 n estimators treinado e registrado no MLflow.
# 2025/11/02 01:50:06 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:50:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Gradient Boosting with 10 max depth treinado e registrado no MLflow.
# 2025/11/02 01:50:16 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:50:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo Gradient Boosting with 200 n estimators and 10 max depth treinado e registrado no MLflow.
# Resultado da comparação:
#                                               Modelo  Acurácia  F1-Score  \
# 2                Gradient Boosting with 10 max depth  0.821229  0.818174
# 3  Gradient Boosting with 200 n estimators and 10...  0.821229  0.817477
# 1            Gradient Boosting with 200 n estimators  0.810056  0.807491
# 0                                  Gradient Boosting  0.804469  0.800754
#
#    Tempo de Treinamento (s)  \
# 2                  3.065399
# 3                  6.352979
# 1                  1.946008
# 0                  1.214474
#
#                                                model  \
# 2  ([DecisionTreeRegressor(criterion='friedman_ms...
# 3  ([DecisionTreeRegressor(criterion='friedman_ms...
# 1  ([DecisionTreeRegressor(criterion='friedman_ms...
# 0  ([DecisionTreeRegressor(criterion='friedman_ms...
#
#                                               params
# 2              {'random_state': 42, 'max_depth': 10}
# 3  {'random_state': 42, 'n_estimators': 200, 'max...
# 1          {'random_state': 42, 'n_estimators': 200}
# 0                               {'randon_state': 42}
# Melhor Modelo: Gradient Boosting with 10 max depth

# %% [markdown]
# #### Best of best

# %%
best_results = pd.concat([best_radon_forest.to_frame().T,
                         best_logistic_regression.to_frame().T,
                         best_k_neighbors_classifier.to_frame().T,
                         best_gradient_boosting_classifier.to_frame().T],
                         ignore_index=True,
                         sort=False)

best_results.head()
best_result = check_best_df(best_results)
# Out:
# Resultado da comparação:
#                                          Modelo  Acurácia  F1-Score  \
# 1  Logistic Regression with False fit intercept  0.821229  0.819935
# 0                                 Random Forest  0.821229  0.818174
# 3           Gradient Boosting with 10 max depth  0.821229  0.818174
# 2   K Neighbors Classifier with 10 in neighbors  0.810056  0.805268
#
#   Tempo de Treinamento (s)                                              model  \
# 1                 0.057311  LogisticRegression(fit_intercept=False, max_it...
# 0                 0.442809  (DecisionTreeClassifier(max_features='sqrt', r...
# 3                 3.065399  ([DecisionTreeRegressor(criterion='friedman_ms...
# 2                 0.029608               KNeighborsClassifier(n_neighbors=10)
#
#                                               params
# 1  {'max_iter': 1000, 'random_state': 42, 'fit_in...
# 0                               {'random_state': 42}
# 3              {'random_state': 42, 'max_depth': 10}
# 2                                {'n_neighbors': 10}
# Melhor Modelo: Logistic Regression with False fit intercept

# %% [markdown]
# #### Salvando o melhor melhor com hiper parâmetro

# %%
with mlflow.start_run(run_name="Melhor Modelo com hiperparâmetros"):
    mlflow.log_param("Modelo", best_result["Modelo"])
    mlflow.log_metric("Acurácia", best_result["Acurácia"])
    mlflow.log_metric("F1-Score", best_result["F1-Score"])
    mlflow.log_metric("Tempo de Treinamento", best_result["Tempo de Treinamento (s)"])
    mlflow.sklearn.log_model(best_result["model"], "modelo")

best_model_name = best_result["Modelo"]
print(f"Melhor modelo ({best_model_name}) armazenado com sucesso no MLflow.")
# Out:
# 2025/11/02 01:50:20 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/02 01:50:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Melhor modelo (Logistic Regression with False fit intercept) armazenado com sucesso no MLflow.
